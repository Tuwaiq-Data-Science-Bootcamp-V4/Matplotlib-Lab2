# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
x = [1,2,3,4,5,6,7]
y = [1,2,3,5,8,13,20]

plt.plot(x,y);

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
plt.plot(x, marker = 'o', markersize = 10, c ='red', linestyle = '--', linewidth = 3)
plt.plot(y, marker = 'o', markersize = 10, c ='green', linestyle = '--', linewidth = 3)
plt.legend(['Normal','Fast'],shadow = True,  loc = 0);

# %% [markdown]
# # Q4: Display multiple line charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment

#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])

# %%
plt.figure(figsize=[20,10])
plt.suptitle('my data visulaization assignment',fontsize = 20)

plt.subplot(1,3,1)
plt.plot(x_plot1, marker = 'o', markersize = 10, c ='orange', linestyle = '--', linewidth = 3)
plt.plot(y_plot1, marker = 'o', markersize = 10, c ='pink', linestyle = '--', linewidth = 3)
plt.title('First Chart')

plt.subplot(1,3,2)
plt.plot(x_plot2, marker = 'o', markersize = 10, c ='blue', linestyle = '--', linewidth = 3)
plt.plot(y_plot2, marker = 'o', markersize = 10, c ='black', linestyle = '--', linewidth = 3)
plt.title('Second Chart')

plt.subplot(1,3,3)
plt.plot(x_plot3, marker = 'o', markersize = 10, c ='green', linestyle = '--', linewidth = 3)
plt.plot(y_plot3, marker = 'o', markersize = 10, c ='red', linestyle = '--', linewidth = 3)
plt.title('Third Chart');

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
series = np.array(["Preson Break", "Breaking Bad", "Dexter"])
rate = np.array([10, 9, 8])

plt.bar(series, rate, color = ['green','red','pink'],width = 0.5)
plt.xlabel('series',fontsize = 20)
plt.ylabel('rate',fontsize = 20);

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
carAge = [5,7,8,7,2,17,2,9,4,11]
carSpeed = [99,86,87,88,111,86,103,87,94,78]
colors = ['red', 'green', 'blue', 'yellow', 'purple', 'orange', 'pink', 'cyan', 'magenta', 'brown']

plt.scatter(carAge, carSpeed, c=colors, s=350, alpha=0.4)
plt.xlabel('Car Age')
plt.ylabel('Car Speed')
plt.title('Car Age vs Car Speed');

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
python_libraries = ['NumPy', 'Pandas','Matplotlib', 'Seaborn','Plotly','Scikit-learn']
skills = [8, 9, 9, 5, 5, 7]
colors = ['red', 'green', 'blue', 'yellow', 'purple']


plt.pie(skills, labels=python_libraries, colors=colors, explode = [0,0,0.3,0,0,0], shadow=True)
plt.title('Python Libraries Skills')
plt.axis('equal');

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
data = np.random.randint(0,100, size=250)

print(data)

plt.hist(data, bins=15)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram');
# Out:
# [76 31 37 81  1 39 79  9  9 75 46 12 27 59  1 67 92 35 74 24 58 47  3 41
#  42 89 19  4 49 62 25 90 43  1 24 42  0 78 71  6  3 26 57 82 91 92 58 97
#  37 22 16 55 31 46 70 61 95 66 46 55 22 94 24 39 37 14 55 53 91  3 25 45
#   3 29 61 11 16 65  3 52 54 82 53 39  0 59 48 42 79 41 92 99 46 73 71 68
#  51 78  9 77 68  6 35 68 36 80 15 24 28 75 93 14 70 75 32 43 26 14 19  7
#  79  0  9 22 19 67 38  0 87 99 69 66 75 25 62 25 87 58 14 40  8 71 10 80
#  61 54 61 27 21  6 72 40  8 55 84 50 16 61 56 40 63 77 53 10 12 93 38 14
#  54 32 37 87 53  3 84 58 68 62 39 62 88 66 95 10 34 36 37 36 28 66 33 71
#  17 48 29 24  0 59 15 92 92 73 95 68 87 51 65 17 73 29  0  6 13 43  0 63
#  60 26 76 59 32 71 62 49 84 67 21  9 83  5 82 48 13 21 83 47 20 17 18 65
#  25 34 78  4 53 25 17 27 56 39]
