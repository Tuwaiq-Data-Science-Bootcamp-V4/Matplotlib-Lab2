# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
# write your code here ^_^
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
# write your code here ^_^
x = list(range(1,8))
y=[1,2,3,5,8,13,20]
print('X: ',x)
print('Y: ',y)
# Out:
# X:  [1, 2, 3, 4, 5, 6, 7]
# Y:  [1, 2, 3, 5, 8, 13, 20]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
# write your code here ^_^
plt.plot(x,y,label='Normal')
plt.plot(x,y,label='Fast',marker='o',linestyle='--',linewidth=3,markersize=10)
plt.legend()

plt.show()

# %% [markdown]
# # Q4: Display multiple line charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment
plt.figure(figsize=(15,5))
plt.suptitle(' my data visulaization assignment')

#title = First Chart
plt.subplot(1,3,1)
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])

plt.plot(x_plot1,y_plot1)
plt.title('First Chart')


#title = Second Chart
plt.subplot(1,3,2)
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])
plt.plot(x_plot2,y_plot2)
plt.title('Second Chart')


#title = Third Chart
plt.subplot(1,3,3)
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])
plt.plot(x_plot3,y_plot3)
plt.title('Third Chart')
# Out:
# Text(0.5, 1.0, 'Third Chart')

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
# write your code here ^_^
Tv_series=['The Blacklist','Narcos','Lupin']
series_rating= [8.2,9.1,7.4]

colors='green'

plt.bar(Tv_series,series_rating,color=colors,width=0.5)
plt.show()

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
# write your code here ^_^
carAge=[5,7,8,7,2,17,2,9,4,11]
carSpeed=[99,86,87,88,111,86,103,87,94,78]

color = [
    "#FF5733",  
    "#00BFFF",  
    "#32CD32",  
    "#8A2BE2",  
    "#FFD700",  
    "#9400D3",  
    "#FF1493",  
    "#00CED1",  
    "#FFA500",  
    "#1E90FF"   
]

plt.scatter(carAge,carSpeed,color=color,s=350,alpha=0.4)
plt.title('Cars')
plt.xlabel('car age')
plt.ylabel('car speed')
plt.show()

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
# write your code here ^_^
py_lib=['Numpy','Pandas','Matplotlib','Seaborn','Plotly','Scikit-learn']
skill_rate=[7,10,8,6,3,2]

color = [
    "#FF5733",  
    "#00BFFF",  
    "#32CD32",  
    "#FFA500",  
    "#FFD700",  
    "#1E90FF", ]

plt.pie(skill_rate,labels=py_lib,autopct='%1.1f%%',colors=color,shadow=True,explode = [0,0.3,0,0,0,0])
plt.show()

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
histo_values = np.random.randint(1,25000,size=250)

# %%
histo_values.size
# Out:
# 250

# %%
histo_values
# Out:
# array([20178,  6131,  9984, 20265,  6494, 23685, 17261,  2999,  1431,
#         7118, 18487, 15731,  6655,  8865, 20001,   226,  6673, 21101,
#         6505,  8479,  2984, 10454,  1790, 24430, 19088, 10395,  3008,
#         4483,    30, 12395, 21909, 16650,  9699, 14120,  7161, 20266,
#        12645, 24362, 19433,  9520,  5339,  9695,  8986, 20063,  7114,
#        13087,  8955,  2706, 11137, 11364, 20166, 17184,  8315, 18103,
#         8757,  5497,  6860,   184, 13510,  7148, 16982, 14960, 16991,
#          548,  5153, 16200, 22774, 21459, 15407, 13312, 19515, 24030,
#        15314, 13111, 12885,  1794, 16335, 21884,  6372, 11670, 11755,
#        15034, 21076,  5696,  9292, 15669, 15565,  8473,  6457, 13286,
#         4378, 20831,  3557, 20004, 16988, 23527,  3697, 23378, 23165,
#        20027,  6518, 14293, 17290, 20274,  7443, 11627,  6294, 17008,
#         7588,  7386, 22435, 14681, 19800, 18591, 21332,  4663, 21282,
#        17463, 19080, 15074, 22991, 17651, 18859, 18549, 11554,  4366,
#        13897, 12352,  4329, 22646,  8819, 14498,  9014,  9144, 22512,
#        15035, 19387,  3347,  3500,  6224,  1271, 17755, 22786, 18574,
#         2805, 14867,  9130, 19122, 22348, 24934,   708, 14608, 18722,
#         6620,  1339,  9660, 23235, 16692, 22513, 10212,  3706, 19206,
#        11292, 12623, 10461,  5502,  6227, 12643, 14506,  4677,  9522,
#         2726,   603, 19814,  5845, 10571,  3197,  4565, 15919, 17496,
#         7567, 20650, 20786, 20784, 19463,  9824, 12979, 24803, 15110,
#          376, 20208,  2729, 14277,  6554,  4570,  9114,  7071, 11241,
#        18591, 12403,  8180, 13542, 15222, 14064, 15553, 15952, 24128,
#        19294, 17864,  7164, 23850,  8002, 22979, 15087, 13731, 12425,
#        14839, 12640, 20101, 23844, 19290, 20154,  6260,  3601,    62,
#        18775, 22813,   610, 22940,  3705, 22919, 13579, 11075, 17213,
#        11265,  3253, 11820, 11841, 22116, 17362,  3798,  8410,  2830,
#        14376,  1346,  7411,  1071,  7464,  4601, 10341])

# %%
plt.hist(histo_values,bins=15)
# Out:
# (array([14., 13., 16., 19., 17., 20., 14., 18., 17., 16., 17., 20., 21.,
#         17., 11.]),
#  array([   30.        ,  1690.26666667,  3350.53333333,  5010.8       ,
#          6671.06666667,  8331.33333333,  9991.6       , 11651.86666667,
#         13312.13333333, 14972.4       , 16632.66666667, 18292.93333333,
#         19953.2       , 21613.46666667, 23273.73333333, 24934.        ]),
#  <BarContainer object of 15 artists>)
